# %% [markdown]
# <div align="right" style="color:green">
#   <h3>SBIA Youness</h3>
# </div>

# %% [markdown]
# # TP 1: Algos de Tris + Complexité

# %% [markdown]
# ### Les Algorithmes de Tris

# %%
import random
import time
# import timeit 

N=100
list1= [None]*N
def reinit():
    global list1
    for i in range(N):
        list1[i]=(random.randint(1,1546612))
reinit()
print(list1)
# Out:
# [454651, 261634, 184360, 793235, 259155, 1503641, 1300808, 924929, 1138456, 355635, 983384, 644498, 84121, 1109211, 299171, 471666, 430954, 604806, 925888, 321600, 150762, 138382, 42481, 237842, 829182, 534147, 868692, 674223, 1121934, 374088, 1225119, 1117792, 40580, 478258, 604318, 910210, 1151491, 757299, 631600, 1254322, 385071, 566011, 797434, 82282, 1143993, 1249813, 143444, 18416, 255961, 642140, 1191072, 264177, 437152, 48175, 983757, 663245, 805081, 1170869, 536016, 526313, 1384803, 1173917, 419861, 79927, 1442614, 1348596, 658292, 1235430, 107480, 1505137, 894568, 541860, 528114, 163190, 782943, 1488589, 884098, 1090535, 94042, 1289759, 30841, 1045704, 604385, 87695, 690640, 1396766, 554602, 739909, 539103, 1525030, 1449463, 874953, 200828, 78372, 1429140, 1279146, 181221, 1412364, 1028339, 326152]

# %% [markdown]
# 1. **Tri par insertion**

# %%
def trierInsertion(list1,N):

    for i in range(1,N):
        temp=list1[i]
        j=i-1
        while(j>=0 and temp<list1[j]):
            list1[j+1]=list1[j]
            j-=1

        list1[j+1]=temp

print(list1[12])
# Out:
# 84121

# %% [markdown]
# **- Calcul de Complexité**

# %%
moyenT=0

for k in range(10): #from 0 to 9
    reinit()

    debut = time.time()
    trierInsertion(list1,N)
    fin = time.time()

    moyenT+=fin-debut

print(f"Le temps moyen quand N={N} par insertion est: {moyenT/10}")
# Out:
# Le temps moyen quand N=100 par insertion est: 0.00021114349365234376

# %% [markdown]
# 2. **Tri par selection**

# %%
def trierSelection(list1,N):
    for i in range(N-1):
        min_indice=i
        for j in range(i+1,N):
            if list1[min_indice]>list1[j]:
                min_indice=j
        tempsel=list1[i]
        list1[i]=list1[min_indice]
        list1[min_indice]=tempsel

trierSelection(list1,N)
print(list1)
# Out:
# [36886, 122350, 133570, 159193, 175477, 193030, 234394, 237644, 246123, 258454, 265469, 268160, 273412, 296331, 312165, 342327, 344547, 380243, 380661, 389110, 420619, 427685, 431852, 435454, 443583, 445298, 446569, 460312, 485983, 490649, 509827, 530843, 558098, 577399, 591655, 608055, 621213, 630038, 637922, 646795, 648071, 653273, 751459, 752454, 770744, 772632, 774021, 793824, 798706, 801618, 830136, 835697, 850672, 854431, 882164, 912560, 938761, 966990, 971542, 975172, 994512, 1010871, 1017268, 1022373, 1043839, 1046129, 1053987, 1060625, 1085656, 1120787, 1135250, 1143466, 1151670, 1158559, 1184005, 1198885, 1228856, 1228877, 1230905, 1233801, 1237183, 1243316, 1247460, 1286662, 1302960, 1326379, 1348973, 1366808, 1378122, 1382746, 1391930, 1398784, 1424731, 1426805, 1448407, 1504046, 1510833, 1516123, 1523955, 1531101]

# %% [markdown]
# **- Calcul de Complexité**

# %%
moyenT=0

for k in range(10): #from 0 to 9
    reinit()

    debut = time.time()
    trierSelection(list1,N)
    fin = time.time()
    
    moyenT+=fin-debut

print(f"Le temps moyen quand N={N} par selection est: {moyenT/10}")
# Out:
# Le temps moyen quand N=100 par selection est: 0.00021216869354248046

# %% [markdown]
# 3. **Tri par bulles**

# %%
def trierBulles(list1,N):
    for i in range(N-1):
        for j in range(N-(i+1)):
            if list1[j]>list1[j+1]:
                tempsel=list1[j]
                list1[j]=list1[j+1]
                list1[j+1]=tempsel

trierBulles(list1,N)
print(list1)
# Out:
# [516, 32562, 53506, 106467, 120062, 151941, 175998, 177447, 184202, 198893, 201619, 213298, 223890, 232847, 295476, 298904, 302760, 303429, 346931, 378546, 422011, 452231, 467650, 488048, 498053, 516794, 532939, 546531, 569164, 569666, 584901, 585183, 629684, 676569, 685310, 687183, 700196, 710129, 753835, 768172, 779514, 791503, 811935, 814844, 826578, 826799, 843210, 851907, 870653, 873615, 877632, 901197, 905167, 907091, 907546, 924722, 936409, 974162, 977929, 988786, 1000037, 1011468, 1022581, 1031728, 1072887, 1073098, 1081397, 1090118, 1095546, 1104491, 1107452, 1120359, 1155307, 1178880, 1191338, 1212124, 1229346, 1243238, 1248374, 1250946, 1283319, 1289765, 1290379, 1305976, 1334220, 1349392, 1357604, 1358310, 1368648, 1369528, 1380016, 1394312, 1417913, 1426719, 1429757, 1432302, 1457084, 1460909, 1473006, 1534388]

# %% [markdown]
# **- Calcul de Complexité**

# %%
moyenT=0

for k in range(10): #from 0 to 9
    reinit()

    debut = time.time()
    trierBulles(list1,N)
    fin = time.time()
    
    moyenT+=fin-debut

print(f"Le temps moyen quand N={N} par bulles est: {moyenT/10}")
# Out:
# Le temps moyen quand N=100 par bulles est: 0.00041220188140869143

# %% [markdown]
# 4. **Recherche dichotomique**

# %%
def rechdicho(list1,N,val):
    debut = 0
    fin = N - 1

    while debut <= fin:
        milieu = (debut + fin) // 2

        if list1[milieu] == val:
            return milieu  
        elif val < list1[milieu]:
            fin = milieu - 1
        else:
            debut = milieu + 1

    return -1
    
print(rechdicho(list1,N, list1[15]))
# Out:
# 15

# %% [markdown]
# **- Calcul de Complexité**

# %%
moyenT=0

for k in range(10): #from 0 to 9
    reinit()

    debut = time.time()
    rechdicho(list1,N, list1[15])
    fin = time.time()
    
    moyenT+=fin-debut

print(f"Le temps moyen quand N={N} recherche dicho est: {moyenT/10}")
# Out:
# Le temps moyen quand N=100 recherche dicho est: 1.4066696166992188e-06

# %% [markdown]
# 5. **Tri par fusion**

# %%
def tri_par_fusion(liste):
    if len(liste) <= 1:
        return liste
    
    milieu = len(liste) // 2
    gauche = tri_par_fusion(liste[:milieu])
    droite = tri_par_fusion(liste[milieu:])
    
    return fusion(gauche, droite)
    
def fusion(gauche, droite):
    resultat = []
    i = j = 0
    
    while i < len(gauche) and j < len(droite):
        if gauche[i] <= droite[j]:
            resultat.append(gauche[i])
            i += 1
        else:
            resultat.append(droite[j])
            j += 1
    
    resultat.extend(gauche[i:])
    resultat.extend(droite[j:])
    return resultat

# Test
liste_test = tri_par_fusion(list1.copy())
print("Liste triée par fusion:", liste_test[:10], "...")
# Out:
# Liste triée par fusion: [7428, 15725, 20564, 22909, 30030, 100994, 112658, 131819, 136966, 139323] ...

# %% [markdown]
# **- Calcul de Complexité**

# %%
moyenT=0

for k in range(10): #from 0 to 9
    reinit()

    debut = time.time()
    tri_par_fusion(list1)
    fin = time.time()
    
    moyenT+=fin-debut

print(f"Le temps moyen quand N={N} recherche fusion est: {moyenT/10}")
# Out:
# Le temps moyen quand N=100 recherche fusion est: 0.00012941360473632811

# %% [markdown]
# 6. **Tri par Tas (Heap Sort)**

# %%
def entasser(arr, n, i):
    maximum = i
    gauche = 2*i + 1
    droite = 2*i + 2
    
    if gauche < n and arr[gauche] > arr[maximum]:
        maximum = gauche
    if droite < n and arr[droite] > arr[maximum]:
        maximum = droite
    
    if maximum != i:
        arr[i], arr[maximum] = arr[maximum], arr[i]
        entasser(arr, n, maximum)

def trierTas(list1, N):
    # Construire le tas max
    for i in range(N//2 - 1, -1, -1):
        entasser(list1, N, i)
    
    # Extraire les éléments un par un
    for i in range(N-1, 0, -1):
        list1[i], list1[0] = list1[0], list1[i]
        entasser(list1, i, 0)

trierTas(list1, N)
print(list1)
# Out:
# [1109, 51158, 76104, 111468, 120299, 130010, 134435, 137375, 173012, 175261, 233625, 238958, 246630, 258973, 267989, 278197, 304017, 336820, 342367, 352951, 353768, 389438, 416898, 463000, 470733, 488978, 495032, 508067, 513532, 532215, 591287, 605206, 612678, 618949, 647781, 663543, 664008, 679112, 687294, 689026, 703499, 710152, 720594, 750640, 775463, 794935, 804567, 805805, 866646, 870195, 881527, 892795, 902602, 907484, 914121, 917233, 925337, 928169, 932249, 932593, 975485, 975540, 979679, 1020339, 1031790, 1042824, 1045174, 1052107, 1062482, 1069867, 1095783, 1129156, 1149441, 1214081, 1223493, 1230172, 1246973, 1247853, 1260758, 1281242, 1281273, 1306495, 1315691, 1317880, 1321008, 1321436, 1355538, 1377911, 1380119, 1417807, 1418655, 1422467, 1434997, 1436830, 1454989, 1460426, 1479777, 1520725, 1525557, 1541659]

# %% [markdown]
# **- Calcul de Complexité**

# %%
moyenT=0

for k in range(10): #from 0 to 9
    reinit()

    debut = time.time()
    trierTas(list1, N)
    fin = time.time()
    
    moyenT+=fin-debut

print(f"Le temps moyen quand N={N} par tas est: {moyenT/10}")
# Out:
# Le temps moyen quand N=100 par tas est: 0.0001592874526977539

# %% [markdown]
# ### Vérification de la Complexité - Courbes de Comparaison

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in e:\anaconda3\lib\site-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in e:\anaconda3\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in e:\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in e:\anaconda3\lib\site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in e:\anaconda3\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in e:\anaconda3\lib\site-packages (from matplotlib) (2.3.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\lampr\appdata\roaming\python\python313\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in e:\anaconda3\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in e:\anaconda3\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lampr\appdata\roaming\python\python313\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\lampr\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Différentes valeurs de N à tester
tailles = [100, 1000, 10000, 50000]

# Stocker les temps moyens
temps_insertion = []
temps_selection = []
temps_bulles = []
temps_fusion = []
temps_tas = []
temps_dicho = []

# Mesurer les temps
for n in tailles:
    print(f"Testing N = {n}...")
    N_old = N
    N = n
    
    # Tri par insertion
    moyenT = 0
    for k in range(10):
        list1 = [random.randint(0, 1500000) for _ in range(N)]
        debut = time.time()
        trierInsertion(list1, N)
        fin = time.time()
        moyenT += fin - debut
    temps_insertion.append(moyenT / 10)
    
    # Tri par sélection
    moyenT = 0
    for k in range(10):
        reinit()
        debut = time.time()
        trierSelection(list1, N)
        fin = time.time()
        moyenT += fin - debut
    temps_selection.append(moyenT / 10)
    
    # Tri par bulles
    moyenT = 0
    for k in range(10):
        reinit()
        debut = time.time()
        trierBulles(list1, N)
        fin = time.time()
        moyenT += fin - debut
    temps_bulles.append(moyenT / 10)
    
    # Tri par fusion
    moyenT = 0
    for k in range(10):
        reinit()
        debut = time.time()
        tri_par_fusion(list1.copy())
        fin = time.time()
        moyenT += fin - debut
    temps_fusion.append(moyenT / 10)
    
    # Tri par tas
    moyenT = 0
    for k in range(10):
        reinit()
        debut = time.time()
        trierTas(list1, N)
        fin = time.time()
        moyenT += fin - debut
    temps_tas.append(moyenT / 10)
    
    # Recherche dichotomique
    moyenT = 0
    for k in range(10):
        reinit()
        trierInsertion(list1, N)
        val = list1[N // 2]
        debut = time.time()
        rechdicho(list1, N, val)
        fin = time.time()
        moyenT += fin - debut
    temps_dicho.append(moyenT / 10)
    
    N = N_old

print("Mesures terminées!")
# Out:
# Testing N = 100...
# Testing N = 1000...
# Testing N = 10000...
# Testing N = 50000...

# %%
# Convertir en arrays
n = np.array(tailles)
t_insertion = np.array(temps_insertion)
t_selection = np.array(temps_selection)
t_bulles = np.array(temps_bulles)
t_fusion = np.array(temps_fusion)
t_tas = np.array(temps_tas)
t_dicho = np.array(temps_dicho)

# Calculer les normalisations
logn = np.log2(n)
nlogn = n * np.log2(n)

# Créer les graphiques - Un graphique par algorithme
fig, axes = plt.subplots(2, 3, figsize=(18, 12))

# Graphique 1: Tri par Insertion
ax1 = axes[0, 0]
ax1.plot(n, t_insertion / logn, 'd-', label='T / log N', linewidth=2, color='purple')
ax1.plot(n, t_insertion / n, 'o-', label='T / N', linewidth=2, color='blue')
ax1.plot(n, t_insertion / (n * logn), 's-', label='T / (N log N)', linewidth=2, color='green')
ax1.plot(n, t_insertion / (n**2), '^-', label='T / N²', linewidth=2, color='red')
ax1.set_xlabel('Taille N', fontsize=11)
ax1.set_ylabel('Temps normalisé', fontsize=11)
ax1.set_title('Tri par Insertion', fontsize=13, fontweight='bold')
ax1.legend()
ax1.grid(True, alpha=0.3)

# Graphique 2: Tri par Sélection
ax2 = axes[0, 1]
ax2.plot(n, t_selection / logn, 'd-', label='T / log N', linewidth=2, color='purple')
ax2.plot(n, t_selection / n, 'o-', label='T / N', linewidth=2, color='blue')
ax2.plot(n, t_selection / (n * logn), 's-', label='T / (N log N)', linewidth=2, color='green')
ax2.plot(n, t_selection / (n**2), '^-', label='T / N²', linewidth=2, color='red')
ax2.set_xlabel('Taille N', fontsize=11)
ax2.set_ylabel('Temps normalisé', fontsize=11)
ax2.set_title('Tri par Sélection', fontsize=13, fontweight='bold')
ax2.legend()
ax2.grid(True, alpha=0.3)

# Graphique 3: Tri par Bulles
ax3 = axes[0, 2]
ax3.plot(n, t_bulles / logn, 'd-', label='T / log N', linewidth=2, color='purple')
ax3.plot(n, t_bulles / n, 'o-', label='T / N', linewidth=2, color='blue')
ax3.plot(n, t_bulles / (n * logn), 's-', label='T / (N log N)', linewidth=2, color='green')
ax3.plot(n, t_bulles / (n**2), '^-', label='T / N²', linewidth=2, color='red')
ax3.set_xlabel('Taille N', fontsize=11)
ax3.set_ylabel('Temps normalisé', fontsize=11)
ax3.set_title('Tri par Bulles', fontsize=13, fontweight='bold')
ax3.legend()
ax3.grid(True, alpha=0.3)

# Graphique 4: Tri par Fusion
ax4 = axes[1, 0]
ax4.plot(n, t_fusion / logn, 'd-', label='T / log N', linewidth=2, color='purple')
ax4.plot(n, t_fusion / n, 'o-', label='T / N', linewidth=2, color='blue')
ax4.plot(n, t_fusion / (n * logn), 's-', label='T / (N log N)', linewidth=2, color='green')
ax4.plot(n, t_fusion / (n**2), '^-', label='T / N²', linewidth=2, color='red')
ax4.set_xlabel('Taille N', fontsize=11)
ax4.set_ylabel('Temps normalisé', fontsize=11)
ax4.set_title('Tri par Fusion', fontsize=13, fontweight='bold')
ax4.legend()
ax4.grid(True, alpha=0.3)

# Graphique 5: Tri par Tas
ax5 = axes[1, 1]
ax5.plot(n, t_tas / logn, 'd-', label='T / log N', linewidth=2, color='purple')
ax5.plot(n, t_tas / n, 'o-', label='T / N', linewidth=2, color='blue')
ax5.plot(n, t_tas / (n * logn), 's-', label='T / (N log N)', linewidth=2, color='green')
ax5.plot(n, t_tas / (n**2), '^-', label='T / N²', linewidth=2, color='red')
ax5.set_xlabel('Taille N', fontsize=11)
ax5.set_ylabel('Temps normalisé', fontsize=11)
ax5.set_title('Tri par Tas (Heap Sort)', fontsize=13, fontweight='bold')
ax5.legend()
ax5.grid(True, alpha=0.3)

# Graphique 6: Recherche Dichotomique
ax6 = axes[1, 2]
ax6.plot(n, t_dicho / logn, 'd-', label='T / log N', linewidth=2, color='purple')
ax6.plot(n, t_dicho / n, 'o-', label='T / N', linewidth=2, color='blue')
ax6.plot(n, t_dicho / (n * logn), 's-', label='T / (N log N)', linewidth=2, color='green')
ax6.plot(n, t_dicho / (n**2), '^-', label='T / N²', linewidth=2, color='red')
ax6.set_xlabel('Taille N', fontsize=11)
ax6.set_ylabel('Temps normalisé', fontsize=11)
ax6.set_title('Recherche Dichotomique', fontsize=13, fontweight='bold')
ax6.legend()
ax6.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print("\n=== Analyse de Complexité ===")
print("\n📊 Pour chaque algorithme, la courbe HORIZONTALE indique la complexité correcte:")
print("\n1. Tri par Insertion: O(n²) → courbe T/N² (rouge) horizontale")
print("2. Tri par Sélection: O(n²) → courbe T/N² (rouge) horizontale")
print("3. Tri par Bulles: O(n²) → courbe T/N² (rouge) horizontale")
print("4. Tri par Fusion: O(n log n) → courbe T/(N log N) (verte) horizontale")
print("5. Tri par Tas: O(n log n) → courbe T/(N log N) (verte) horizontale")
print("6. Recherche Dichotomique: O(log n) → courbe T/log N (violette) horizontale")
