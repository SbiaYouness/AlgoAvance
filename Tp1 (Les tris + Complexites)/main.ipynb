# %% [markdown]
# <div align="right" style="color:green">
#   <h3>SBIA Youness</h3>
# </div>

# %% [markdown]
# # TP 1: Algos de Tris + Complexité

# %% [markdown]
# ### Les Algorithmes de Tris

# %%
import random
import time
import timeit 

N=100
list1= [None]*N
def reinit():
    global list1
    for i in range(N):
        list1[i]=(random.randint(1,1546612))
reinit()
print(list1)
# Out:
# [1362872, 168387, 605734, 1523301, 1304198, 62573, 1282371, 586745, 1253923, 1065623, 1146789, 984109, 169843, 471881, 370571, 1317840, 360969, 616954, 184572, 761855, 956504, 1530763, 135077, 356110, 1514337, 1121872, 1397089, 466501, 1501209, 412166, 456276, 18010, 413238, 277418, 720555, 338896, 891939, 990207, 484223, 562385, 656974, 111618, 971155, 718525, 871244, 412613, 791437, 182336, 1059890, 959853, 9896, 576339, 719919, 227095, 706599, 876161, 337842, 616582, 402497, 1356160, 471464, 232874, 1298047, 1073764, 800467, 354962, 47927, 845757, 865113, 379587, 1505599, 1056825, 853278, 1438329, 463857, 1060914, 846920, 819308, 242864, 765376, 1136750, 26918, 1259819, 513786, 196276, 605885, 954705, 1272044, 790358, 752434, 1201516, 312878, 1094280, 131308, 67523, 345440, 929694, 98304, 1120574, 1254272]

# %% [markdown]
# 1. **Tri par insertion**

# %%
def trierInsertion(list1,N):

    for i in range(1,N):
        temp=list1[i]
        j=i-1
        while(j>=0 and temp<list1[j]):
            list1[j+1]=list1[j]
            j-=1

        list1[j+1]=temp

print(list1[12])
# Out:
# 169843

# %% [markdown]
# **- Calcul de Complexité**

# %%
moyenT=0

for k in range(10): #from 0 to 9
    reinit()

    debut = time.time()
    trierInsertion(list1,N)
    fin = time.time()

    moyenT+=fin-debut

print(f"Le temps moyen quand N={N} par insertion est: {moyenT/10}")
# Out:
# Le temps moyen quand N=100 par insertion est: 0.0007444143295288086

# %% [markdown]
# 2. **Tri par selection**

# %%
def trierSelection(list1,N):
    for i in range(N-1):
        min_indice=i
        for j in range(i+1,N):
            if list1[min_indice]>list1[j]:
                min_indice=j
        tempsel=list1[i]
        list1[i]=list1[min_indice]
        list1[min_indice]=tempsel

trierSelection(list1,N)
print(list1)
# Out:
# [2011, 2369, 10367, 36107, 60389, 76027, 76396, 82960, 95598, 98567, 123340, 136589, 138210, 139230, 184231, 187064, 216496, 225977, 228203, 249666, 254948, 277022, 315259, 319226, 375746, 410839, 419505, 434836, 443566, 449678, 478632, 480450, 497404, 516412, 523088, 533646, 540297, 550909, 558577, 586326, 586727, 588312, 592007, 607388, 607489, 630992, 645036, 655504, 720981, 729609, 730217, 730238, 787230, 821764, 823043, 837269, 839079, 843031, 846041, 882060, 896658, 897142, 906331, 914649, 921088, 924578, 961150, 969023, 994414, 1001078, 1007413, 1016351, 1019871, 1027300, 1042967, 1044846, 1073944, 1084991, 1120351, 1136716, 1177311, 1201409, 1201511, 1204708, 1239311, 1276588, 1286163, 1291167, 1304988, 1311250, 1332946, 1339510, 1360252, 1378936, 1426425, 1447560, 1508121, 1524595, 1525038, 1533337]

# %% [markdown]
# **- Calcul de Complexité**

# %%
moyenT=0

for k in range(10): #from 0 to 9
    reinit()

    debut = time.time()
    trierSelection(list1,N)
    fin = time.time()
    
    moyenT+=fin-debut

print(f"Le temps moyen quand N={N} par selection est: {moyenT/10}")
# Out:
# Le temps moyen quand N=100 par selection est: 0.0

# %% [markdown]
# 3. **Tri par bulles**

# %%
def trierBulles(list1,N):
    for i in range(N-1):
        for j in range(N-(i+1)):
            if list1[j]>list1[j+1]:
                tempsel=list1[j]
                list1[j]=list1[j+1]
                list1[j+1]=tempsel

trierBulles(list1,N)
print(list1)
# Out:
# [14679, 17015, 18749, 39576, 56388, 92057, 96426, 105210, 113295, 117926, 123131, 126697, 194783, 202843, 208734, 242415, 248538, 306377, 330100, 365299, 395690, 406889, 438866, 443807, 444629, 455331, 460153, 470658, 497447, 504763, 525872, 533065, 549884, 558434, 579964, 585194, 593558, 616900, 629311, 629641, 645828, 696874, 708392, 714898, 719296, 719619, 737970, 740836, 758275, 763992, 766319, 781709, 792530, 812907, 815303, 821709, 851944, 864258, 903974, 917066, 918097, 1008027, 1044580, 1081770, 1094799, 1096952, 1117864, 1120256, 1128320, 1141067, 1155458, 1162270, 1169678, 1187149, 1189851, 1192417, 1203526, 1207848, 1207912, 1215166, 1254012, 1258360, 1266026, 1288901, 1289563, 1307748, 1313956, 1327208, 1328334, 1341447, 1369105, 1389364, 1391526, 1395328, 1427980, 1435497, 1438754, 1456397, 1458727, 1529126]

# %% [markdown]
# **- Calcul de Complexité**

# %%
moyenT=0

for k in range(10): #from 0 to 9
    reinit()

    debut = time.time()
    trierBulles(list1,N)
    fin = time.time()
    
    moyenT+=fin-debut

print(f"Le temps moyen quand N={N} par bulles est: {moyenT/10}")
# Out:
# Le temps moyen quand N=100 par bulles est: 0.0009830236434936524

# %% [markdown]
# 4. **Recherche dichotomique**

# %%
def rechdicho(list1,N,val):
    debut = 0
    fin = N - 1

    while debut <= fin:
        milieu = (debut + fin) // 2

        if list1[milieu] == val:
            return milieu  
        elif val < list1[milieu]:
            fin = milieu - 1
        else:
            debut = milieu + 1

    return -1
    
print(rechdicho(list1,N, list1[15]))
# Out:
# 15

# %% [markdown]
# **- Calcul de Complexité**

# %%
moyenT=0

for k in range(10): #from 0 to 9
    reinit()

    debut = time.time()
    rechdicho(list1,N, list1[15])
    fin = time.time()
    
    moyenT+=fin-debut

print(f"Le temps moyen quand N={N} recherche dicho est: {moyenT/10}")
# Out:
# Le temps moyen quand N=100 recherche dicho est: 0.0

# %% [markdown]
# 5. **Tri par fusion**

# %%
def tri_par_fusion(liste):
    if len(liste) <= 1:
        return liste
    
    milieu = len(liste) // 2
    gauche = tri_par_fusion(liste[:milieu])
    droite = tri_par_fusion(liste[milieu:])
    
    return fusion(gauche, droite)
    
def fusion(gauche, droite):
    resultat = []
    i = j = 0
    
    while i < len(gauche) and j < len(droite):
        if gauche[i] <= droite[j]:
            resultat.append(gauche[i])
            i += 1
        else:
            resultat.append(droite[j])
            j += 1
    
    resultat.extend(gauche[i:])
    resultat.extend(droite[j:])
    return resultat

# Test
liste_test = tri_par_fusion(list1.copy())
print("Liste triée par fusion:", liste_test[:10], "...")
# Out:
# Liste triée par fusion: [35888, 39831, 63694, 81991, 104183, 114786, 116204, 123245, 149650, 157169] ...

# %% [markdown]
# **- Calcul de Complexité**

# %%
moyenT=0

for k in range(10): #from 0 to 9
    reinit()

    debut = time.time()
    tri_par_fusion(list1)
    fin = time.time()
    
    moyenT+=fin-debut

print(f"Le temps moyen quand N={N} recherche fusion est: {moyenT/10}")
# Out:
# Le temps moyen quand N=100 recherche fusion est: 0.0

# %% [markdown]
# 6. **Tri par Tas (Heap Sort)**

# %%
def entasser(arr, n, i):
    maximum = i
    gauche = 2*i + 1
    droite = 2*i + 2
    
    if gauche < n and arr[gauche] > arr[maximum]:
        maximum = gauche
    if droite < n and arr[droite] > arr[maximum]:
        maximum = droite
    
    if maximum != i:
        arr[i], arr[maximum] = arr[maximum], arr[i]
        entasser(arr, n, maximum)

def trierTas(list1, N):
    # Construire le tas max
    for i in range(N//2 - 1, -1, -1):
        entasser(list1, N, i)
    
    # Extraire les éléments un par un
    for i in range(N-1, 0, -1):
        list1[i], list1[0] = list1[0], list1[i]
        entasser(list1, i, 0)

trierTas(list1, N)
print(list1)
# Out:
# [32271, 96471, 100044, 115163, 127207, 162197, 162636, 169711, 183361, 201534, 210695, 215075, 231883, 274154, 299846, 312600, 314163, 316535, 321776, 358206, 361800, 374771, 384147, 391731, 405413, 406078, 411237, 460732, 476192, 478877, 484099, 499018, 533326, 558629, 575530, 596193, 596625, 621389, 640057, 640548, 646979, 665585, 670130, 706334, 721461, 734042, 761316, 762417, 777577, 794345, 817675, 840651, 844762, 851477, 866164, 911831, 914046, 914510, 929813, 933997, 954292, 985668, 990333, 990551, 993547, 1016022, 1057899, 1070835, 1072104, 1099689, 1100501, 1104504, 1123269, 1130923, 1134332, 1190633, 1212775, 1213105, 1224928, 1254107, 1283778, 1294878, 1298121, 1309101, 1324840, 1334103, 1340400, 1342674, 1347385, 1361066, 1375045, 1380388, 1384809, 1385892, 1389830, 1396886, 1429123, 1434476, 1442447, 1456527]

# %% [markdown]
# **- Calcul de Complexité**

# %%
moyenT=0

for k in range(10): #from 0 to 9
    reinit()

    debut = time.time()
    trierTas(list1, N)
    fin = time.time()
    
    moyenT+=fin-debut

print(f"Le temps moyen quand N={N} par tas est: {moyenT/10}")
# Out:
# Le temps moyen quand N=100 par tas est: 0.00011606216430664063

# %% [markdown]
# ### Vérification de la Complexité - Courbes de Comparaison

# %%
pip install ipykernel -U --user --force-reinstall
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\lampr\appdata\local\programs\python\python310\lib\site-packages (3.10.7)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\lampr\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\lampr\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lampr\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\lampr\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\lampr\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (2.1.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\lampr\appdata\roaming\python\python310\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\lampr\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\lampr\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lampr\appdata\roaming\python\python310\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\lampr\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -ygments (c:\users\lampr\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -ygments (c:\users\lampr\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -ygments (c:\users\lampr\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -ygments (c:\users\lampr\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -ygments (c:\users\lampr\appdata\roaming\python\python310\site-packages)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
import numpy as np

# Différentes valeurs de N à tester
tailles = [100, 1000, 10000, 100000]

# Stocker les temps moyens
temps_insertion = []
temps_selection = []
temps_bulles = []
temps_fusion = []
temps_tas = []
temps_dicho = []

# Mesurer les temps
for n in tailles:
    print(f"Testing N = {n}...")
    N_old = N
    N = n
    
    # Tri par insertion
    moyenT = 0
    for k in range(10):
        list1 = [random.randint(0, 1500000) for _ in range(N)]
        debut = time.time()
        trierInsertion(list1, N)
        fin = time.time()
        moyenT += fin - debut
    temps_insertion.append(moyenT / 10)
    
    # Tri par sélection
    moyenT = 0
    for k in range(10):
        reinit()
        debut = time.time()
        trierSelection(list1, N)
        fin = time.time()
        moyenT += fin - debut
    temps_selection.append(moyenT / 10)
    
    # Tri par bulles
    moyenT = 0
    for k in range(10):
        reinit()
        debut = time.time()
        trierBulles(list1, N)
        fin = time.time()
        moyenT += fin - debut
    temps_bulles.append(moyenT / 10)
    
    # Tri par fusion
    moyenT = 0
    for k in range(10):
        reinit()
        debut = time.time()
        tri_par_fusion(list1.copy())
        fin = time.time()
        moyenT += fin - debut
    temps_fusion.append(moyenT / 10)
    
    # Tri par tas
    moyenT = 0
    for k in range(10):
        reinit()
        debut = time.time()
        trierTas(list1, N)
        fin = time.time()
        moyenT += fin - debut
    temps_tas.append(moyenT / 10)
    
    # Recherche dichotomique
    moyenT = 0
    for k in range(10):
        reinit()
        trierInsertion(list1, N)
        val = list1[N // 2]
        debut = time.time()
        rechdicho(list1, N, val)
        fin = time.time()
        moyenT += fin - debut
    temps_dicho.append(moyenT / 10)
    
    N = N_old

print("Mesures terminées!")
# Out:
# Testing N = 100...
# Testing N = 1000...
# Testing N = 10000...
# Collecting ipykernel
#   Using cached ipykernel-7.1.0-py3-none-any.whl.metadata (4.5 kB)
# Collecting comm>=0.1.1 (from ipykernel)
#   Using cached comm-0.2.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting debugpy>=1.6.5 (from ipykernel)
#   Using cached debugpy-1.8.17-cp310-cp310-win_amd64.whl.metadata (1.5 kB)
# Collecting ipython>=7.23.1 (from ipykernel)
#   Using cached ipython-8.37.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting jupyter-client>=8.0.0 (from ipykernel)
#   Using cached jupyter_client-8.6.3-py3-none-any.whl.metadata (8.3 kB)
# Collecting jupyter-core!=5.0.*,>=4.12 (from ipykernel)
#   Using cached jupyter_core-5.9.1-py3-none-any.whl.metadata (1.5 kB)
# Collecting matplotlib-inline>=0.1 (from ipykernel)
#   Using cached matplotlib_inline-0.2.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting nest-asyncio>=1.4 (from ipykernel)
#   Using cached nest_asyncio-1.6.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting packaging>=22 (from ipykernel)
#   Using cached packaging-25.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting psutil>=5.7 (from ipykernel)
#   Using cached psutil-7.1.3-cp37-abi3-win_amd64.whl.metadata (23 kB)
# Collecting pyzmq>=25 (from ipykernel)
#   Using cached pyzmq-27.1.0-cp310-cp310-win_amd64.whl.metadata (6.0 kB)
# Collecting tornado>=6.2 (from ipykernel)
#   Using cached tornado-6.5.2-cp39-abi3-win_amd64.whl.metadata (2.9 kB)
# Collecting traitlets>=5.4.0 (from ipykernel)
#   Using cached traitlets-5.14.3-py3-none-any.whl.metadata (10 kB)
# Collecting colorama (from ipython>=7.23.1->ipykernel)
#   Using cached colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Collecting decorator (from ipython>=7.23.1->ipykernel)
#   Using cached decorator-5.2.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting exceptiongroup (from ipython>=7.23.1->ipykernel)
#   Using cached exceptiongroup-1.3.0-py3-none-any.whl.metadata (6.7 kB)
# Collecting jedi>=0.16 (from ipython>=7.23.1->ipykernel)
#   Using cached jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting prompt_toolkit<3.1.0,>=3.0.41 (from ipython>=7.23.1->ipykernel)
#   Using cached prompt_toolkit-3.0.52-py3-none-any.whl.metadata (6.4 kB)
# Collecting pygments>=2.4.0 (from ipython>=7.23.1->ipykernel)
#   Using cached pygments-2.19.2-py3-none-any.whl.metadata (2.5 kB)
# Collecting stack_data (from ipython>=7.23.1->ipykernel)
#   Using cached stack_data-0.6.3-py3-none-any.whl.metadata (18 kB)
# Collecting typing_extensions>=4.6 (from ipython>=7.23.1->ipykernel)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting python-dateutil>=2.8.2 (from jupyter-client>=8.0.0->ipykernel)
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting platformdirs>=2.5 (from jupyter-core!=5.0.*,>=4.12->ipykernel)
#   Using cached platformdirs-4.5.0-py3-none-any.whl.metadata (12 kB)
# Collecting parso<0.9.0,>=0.8.4 (from jedi>=0.16->ipython>=7.23.1->ipykernel)
#   Using cached parso-0.8.5-py2.py3-none-any.whl.metadata (8.3 kB)
# Collecting wcwidth (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel)
#   Using cached wcwidth-0.2.14-py2.py3-none-any.whl.metadata (15 kB)
# Collecting six>=1.5 (from python-dateutil>=2.8.2->jupyter-client>=8.0.0->ipykernel)
#   Using cached six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting executing>=1.2.0 (from stack_data->ipython>=7.23.1->ipykernel)
#   Using cached executing-2.2.1-py2.py3-none-any.whl.metadata (8.9 kB)
# Collecting asttokens>=2.1.0 (from stack_data->ipython>=7.23.1->ipykernel)
#   Using cached asttokens-3.0.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting pure-eval (from stack_data->ipython>=7.23.1->ipykernel)
#   Using cached pure_eval-0.2.3-py3-none-any.whl.metadata (6.3 kB)
# Using cached ipykernel-7.1.0-py3-none-any.whl (117 kB)
# Using cached comm-0.2.3-py3-none-any.whl (7.3 kB)
# Using cached debugpy-1.8.17-cp310-cp310-win_amd64.whl (5.3 MB)
# Using cached ipython-8.37.0-py3-none-any.whl (831 kB)
# Using cached jupyter_client-8.6.3-py3-none-any.whl (106 kB)
# Using cached jupyter_core-5.9.1-py3-none-any.whl (29 kB)
# Using cached matplotlib_inline-0.2.1-py3-none-any.whl (9.5 kB)
# Using cached nest_asyncio-1.6.0-py3-none-any.whl (5.2 kB)
# Using cached packaging-25.0-py3-none-any.whl (66 kB)
# Using cached psutil-7.1.3-cp37-abi3-win_amd64.whl (247 kB)
# Using cached pyzmq-27.1.0-cp310-cp310-win_amd64.whl (632 kB)
# Using cached tornado-6.5.2-cp39-abi3-win_amd64.whl (445 kB)
# Using cached traitlets-5.14.3-py3-none-any.whl (85 kB)
# Using cached jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
# Using cached platformdirs-4.5.0-py3-none-any.whl (18 kB)
# Using cached prompt_toolkit-3.0.52-py3-none-any.whl (391 kB)
# Using cached pygments-2.19.2-py3-none-any.whl (1.2 MB)
# Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Using cached colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Using cached decorator-5.2.1-py3-none-any.whl (9.2 kB)
# Using cached exceptiongroup-1.3.0-py3-none-any.whl (16 kB)
# Using cached stack_data-0.6.3-py3-none-any.whl (24 kB)
# Using cached asttokens-3.0.0-py3-none-any.whl (26 kB)
# Using cached executing-2.2.1-py2.py3-none-any.whl (28 kB)
# Using cached parso-0.8.5-py2.py3-none-any.whl (106 kB)
# Using cached six-1.17.0-py2.py3-none-any.whl (11 kB)
# Using cached pure_eval-0.2.3-py3-none-any.whl (11 kB)
# Using cached wcwidth-0.2.14-py2.py3-none-any.whl (37 kB)
# Installing collected packages: pure-eval, wcwidth, typing_extensions, traitlets, tornado, six, pyzmq, pygments, psutil, platformdirs, parso, packaging, nest-asyncio, executing, decorator, debugpy, comm, colorama, asttokens, stack_data, python-dateutil, prompt_toolkit, matplotlib-inline, jupyter-core, jedi, exceptiongroup, jupyter-client, ipython, ipykernel
#   Attempting uninstall: pure-eval
#     Found existing installation: pure_eval 0.2.3
#     Uninstalling pure_eval-0.2.3:
#       Successfully uninstalled pure_eval-0.2.3
#   Attempting uninstall: wcwidth
#     Found existing installation: wcwidth 0.2.14
#     Uninstalling wcwidth-0.2.14:
#       Successfully uninstalled wcwidth-0.2.14
#   Attempting uninstall: typing_extensions
#     Found existing installation: typing_extensions 4.15.0
#     Uninstalling typing_extensions-4.15.0:
#       Successfully uninstalled typing_extensions-4.15.0
#   Attempting uninstall: traitlets
#     Found existing installation: traitlets 5.14.3
#     Uninstalling traitlets-5.14.3:
#       Successfully uninstalled traitlets-5.14.3
#   Attempting uninstall: tornado
#     Found existing installation: tornado 6.5.2
#     Uninstalling tornado-6.5.2:
#       Successfully uninstalled tornado-6.5.2
#   Attempting uninstall: six
#     Found existing installation: six 1.17.0
#     Uninstalling six-1.17.0:
#       Successfully uninstalled six-1.17.0
#   Attempting uninstall: pyzmq
#     Found existing installation: pyzmq 27.1.0
#     Uninstalling pyzmq-27.1.0:
#       Successfully uninstalled pyzmq-27.1.0
#   Attempting uninstall: pygments
#     Found existing installation: Pygments 2.19.2
#     Uninstalling Pygments-2.19.2:
#       Successfully uninstalled Pygments-2.19.2
#   Attempting uninstall: psutil
#     Found existing installation: psutil 7.1.3
#     Uninstalling psutil-7.1.3:
#       Successfully uninstalled psutil-7.1.3
#   Attempting uninstall: platformdirs
#     Found existing installation: platformdirs 4.5.0
#     Uninstalling platformdirs-4.5.0:
#       Successfully uninstalled platformdirs-4.5.0
#   Attempting uninstall: parso
#     Found existing installation: parso 0.8.5
#     Uninstalling parso-0.8.5:
#       Successfully uninstalled parso-0.8.5
#   Attempting uninstall: packaging
#     Found existing installation: packaging 25.0
#     Uninstalling packaging-25.0:
#       Successfully uninstalled packaging-25.0
#   Attempting uninstall: nest-asyncio
#     Found existing installation: nest-asyncio 1.6.0
#     Uninstalling nest-asyncio-1.6.0:
#       Successfully uninstalled nest-asyncio-1.6.0
#   Attempting uninstall: executing
#     Found existing installation: executing 2.2.1
#     Uninstalling executing-2.2.1:
#       Successfully uninstalled executing-2.2.1
#   Attempting uninstall: decorator
#     Found existing installation: decorator 5.2.1
#     Uninstalling decorator-5.2.1:
#       Successfully uninstalled decorator-5.2.1
#   Attempting uninstall: debugpy
#     Found existing installation: debugpy 1.8.17
#     Uninstalling debugpy-1.8.17:
#       Successfully uninstalled debugpy-1.8.17
#   Attempting uninstall: comm
#     Found existing installation: comm 0.2.3
#     Uninstalling comm-0.2.3:
#       Successfully uninstalled comm-0.2.3
#   Attempting uninstall: colorama
#     Found existing installation: colorama 0.4.6
#     Uninstalling colorama-0.4.6:
#       Successfully uninstalled colorama-0.4.6
#   Attempting uninstall: asttokens
#     Found existing installation: asttokens 3.0.0
#     Uninstalling asttokens-3.0.0:
#       Successfully uninstalled asttokens-3.0.0
#   Attempting uninstall: stack_data
#     Found existing installation: stack-data 0.6.3
#     Uninstalling stack-data-0.6.3:
#       Successfully uninstalled stack-data-0.6.3
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.9.0.post0
#     Uninstalling python-dateutil-2.9.0.post0:
#       Successfully uninstalled python-dateutil-2.9.0.post0
#   Attempting uninstall: prompt_toolkit
#     Found existing installation: prompt_toolkit 3.0.52
#     Uninstalling prompt_toolkit-3.0.52:
#       Successfully uninstalled prompt_toolkit-3.0.52
#   Attempting uninstall: matplotlib-inline
#     Found existing installation: matplotlib-inline 0.2.1
#     Uninstalling matplotlib-inline-0.2.1:
#       Successfully uninstalled matplotlib-inline-0.2.1
#   Attempting uninstall: jupyter-core
#     Found existing installation: jupyter_core 5.9.1
#     Uninstalling jupyter_core-5.9.1:
#       Successfully uninstalled jupyter_core-5.9.1
#   Attempting uninstall: jedi
#     Found existing installation: jedi 0.19.2
#     Uninstalling jedi-0.19.2:
#       Successfully uninstalled jedi-0.19.2
#   Attempting uninstall: exceptiongroup
#     Found existing installation: exceptiongroup 1.3.0
#     Uninstalling exceptiongroup-1.3.0:
#       Successfully uninstalled exceptiongroup-1.3.0
#   Attempting uninstall: jupyter-client
#     Found existing installation: jupyter_client 8.6.3
#     Uninstalling jupyter_client-8.6.3:
#       Successfully uninstalled jupyter_client-8.6.3
#   Attempting uninstall: ipython
#     Found existing installation: ipython 8.37.0
#     Uninstalling ipython-8.37.0:
#       Successfully uninstalled ipython-8.37.0
#   Attempting uninstall: ipykernel
#     Found existing installation: ipykernel 7.1.0
#     Uninstalling ipykernel-7.1.0:
#       Successfully uninstalled ipykernel-7.1.0
# Successfully installed asttokens-3.0.0 colorama-0.4.6 comm-0.2.3 debugpy-1.8.17 decorator-5.2.1 exceptiongroup-1.3.0 executing-2.2.1 ipykernel-7.1.0 ipython-8.37.0 jedi-0.19.2 jupyter-client-8.6.3 jupyter-core-5.9.1 matplotlib-inline-0.2.1 nest-asyncio-1.6.0 packaging-25.0 parso-0.8.5 platformdirs-4.5.0 prompt_toolkit-3.0.52 psutil-7.1.3 pure-eval-0.2.3 pygments-2.19.2 python-dateutil-2.9.0.post0 pyzmq-27.1.0 six-1.17.0 stack_data-0.6.3 tornado-6.5.2 traitlets-5.14.3 typing_extensions-4.15.0 wcwidth-0.2.14
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\lampr\AppData\Roaming\Python\Python310\site-packages\~-rnado'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\lampr\AppData\Roaming\Python\Python310\site-packages\~-q'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\lampr\AppData\Roaming\Python\Python310\site-packages\~-util'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\lampr\AppData\Roaming\Python\Python310\site-packages\~-bugpy'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# huggingface-hub 0.26.2 requires pyyaml>=5.1, which is not installed.
# langchain-core 0.3.15 requires PyYAML>=5.3, which is not installed.
# langchain-ollama 0.2.0 requires ollama<1,>=0.3.0, which is not installed.
# transformers 4.46.2 requires pyyaml>=5.1, which is not installed.
# langchain-core 0.3.15 requires packaging<25,>=23.2, but you have packaging 25.0 which is incompatible.
#
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 46
#      44 reinit()
#      45 debut = time.time()
# ---> 46 trierBulles(list1, N)
#      47 fin = time.time()
#      48 moyenT += fin - debut
#
# Cell In[6], line -1, in trierBulles(list1, N)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# KeyboardInterrupt:

# %%
# Convertir en arrays
n = np.array(tailles)
t_insertion = np.array(temps_insertion)
t_selection = np.array(temps_selection)
t_bulles = np.array(temps_bulles)
t_fusion = np.array(temps_fusion)
t_tas = np.array(temps_tas)
t_dicho = np.array(temps_dicho)

# Créer les graphiques
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# Graphique 1: Algorithmes O(n²) - Temps / n²
ax1 = axes[0]
ax1.plot(n, t_insertion / (n**2), 'o-', label='Insertion', linewidth=2)
ax1.plot(n, t_selection / (n**2), 's-', label='Sélection', linewidth=2)
ax1.plot(n, t_bulles / (n**2), '^-', label='Bulles', linewidth=2)
ax1.set_xlabel('Taille N', fontsize=12)
ax1.set_ylabel('Temps / N²', fontsize=12)
ax1.set_title('Algorithmes O(n²)', fontsize=14, fontweight='bold')
ax1.legend()
ax1.grid(True, alpha=0.3)

# Graphique 2: Algorithmes O(n log n) - Temps / (n log n)
ax2 = axes[1]
nlogn = n * np.log2(n)
ax2.plot(n, t_fusion / nlogn, 'o-', label='Fusion', linewidth=2, color='green')
ax2.plot(n, t_tas / nlogn, 's-', label='Tas', linewidth=2, color='orange')
ax2.set_xlabel('Taille N', fontsize=12)
ax2.set_ylabel('Temps / (N log N)', fontsize=12)
ax2.set_title('Algorithmes O(n log n)', fontsize=14, fontweight='bold')
ax2.legend()
ax2.grid(True, alpha=0.3)

# Graphique 3: Recherche O(log n) - Temps / log n
ax3 = axes[2]
logn = np.log2(n)
ax3.plot(n, t_dicho / logn, 'o-', label='Recherche Dicho', linewidth=2, color='red')
ax3.set_xlabel('Taille N', fontsize=12)
ax3.set_ylabel('Temps / log N', fontsize=12)
ax3.set_title('Recherche O(log n)', fontsize=14, fontweight='bold')
ax3.legend()
ax3.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print("\n=== Analyse ===")
print("Courbe horizontale = complexité correcte")
print("- Insertion, Sélection, Bulles: O(n²)")
print("- Fusion, Tas: O(n log n)")
print("- Recherche Dichotomique: O(log n)")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 15
#      13 # Graphique 1: Algorithmes O(n²) - Temps / n²
#      14 ax1 = axes[0]
# ---> 15 ax1.plot(n, t_insertion / (n**2), 'o-', label='Insertion', linewidth=2)
#      16 ax1.plot(n, t_selection / (n**2), 's-', label='Sélection', linewidth=2)
#      17 ax1.plot(n, t_bulles / (n**2), '^-', label='Bulles', linewidth=2)
#
# ValueError: operands could not be broadcast together with shapes (3,) (4,)
